# %% [markdown]
# # **NASNet - Post GAN**

# %%
import numpy as np
import tensorflow as tf
import os
import matplotlib.pyplot as plt
from tensorflow.keras import layers as L
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# %%
# DataLoader
train_data = tf.keras.utils.image_dataset_from_directory(
    '/kaggle/input/adversarial-gtsrb-data/Adversarial-GTSRB-Data',
    batch_size=128,
    image_size=(32, 32),
    label_mode="categorical",
    labels = "inferred",
    validation_split=0.2,
    subset='training',
    seed=42,
)

val_data = tf.keras.utils.image_dataset_from_directory(
    '/kaggle/input/adversarial-gtsrb-data/Adversarial-GTSRB-Data',
    batch_size=128,
    label_mode="categorical",
    labels = "inferred",
    image_size=(32, 32),
    validation_split=0.2,
    subset='validation',
    seed=42,
)
# Out:
# Found 211209 files belonging to 43 classes.
# Using 168968 files for training.
# Found 211209 files belonging to 43 classes.
# Using 42241 files for validation.

# %%
train_data.as_numpy_iterator().__next__()[0].shape
# Out:
# (128, 32, 32, 3)

# %%
train_data.as_numpy_iterator().__next__()[1].shape
# Out:
# (128, 43)

# %%
# Create custom F1 Score Metrics

from keras import backend as K

def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

# %%
steps_per_epoch = len(train_data)
EPOCHS = 128

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=4, min_lr=0.000001)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", # watch the val loss metric
                                                  patience=8,# if val loss decreases for 8 epochs in a row, stop training
                                                  restore_best_weights = True)

# %%
# Model

def create_model(shape=(32, 32, 3)):
    base_model = tf.keras.applications.nasnet.NASNetLarge(
        include_top = False,
        input_shape = shape,
        weights = "imagenet",
    )
    
    base_model.trainable = False
    for layer in base_model.layers[-7:]:
        layer.trainable = True
        
    x = base_model.output
    x = L.Flatten(name="flatten")(x)
    x = L.Dense(512, activation="relu", name="Dense-1")(x)
    x = L.Dropout(0.4, name="Final-Dropout")(x)
    x = L.Dense(43, activation="softmax", name="Output-layer")(x)
    
    model = tf.keras.models.Model(base_model.input, x, name="NASNet")
    model.compile(
        loss="categorical_crossentropy",
        optimizer="Adam",
        metrics = ["accuracy",
                  tf.keras.metrics.TruePositives(name='true_positives'),
                  tf.keras.metrics.TrueNegatives(name='true_negatives'),
                  tf.keras.metrics.FalsePositives(name='false_positives'),
                  tf.keras.metrics.FalseNegatives(name='false_negatives')]
    )
    
    return model

# %%
model = create_model()

# Fit the model
history = model.fit(
    train_data,
    epochs = EPOCHS,
    steps_per_epoch = steps_per_epoch,
    validation_data = val_data,
    validation_steps = len(val_data),
    callbacks = [reduce_lr, early_stopping],
)
# Out:
# Epoch 1/128
# 1321/1321 [==============================] - 150s 100ms/step - loss: 3.7585 - accuracy: 0.0351 - true_positives: 39.0000 - true_negatives: 7095859.0000 - false_positives: 797.0000 - false_negatives: 168929.0000 - val_loss: 3.6343 - val_accuracy: 0.0514 - val_true_positives: 10.0000 - val_true_negatives: 1774114.0000 - val_false_positives: 8.0000 - val_false_negatives: 42231.0000 - lr: 0.0010
# Epoch 2/128
# 1321/1321 [==============================] - 124s 94ms/step - loss: 3.6361 - accuracy: 0.0504 - true_positives: 23.0000 - true_negatives: 7096617.0000 - false_positives: 39.0000 - false_negatives: 168945.0000 - val_loss: 3.5556 - val_accuracy: 0.0740 - val_true_positives: 7.0000 - val_true_negatives: 1774117.0000 - val_false_positives: 5.0000 - val_false_negatives: 42234.0000 - lr: 0.0010
# Epoch 3/128
# 1321/1321 [==============================] - 125s 94ms/step - loss: 3.6163 - accuracy: 0.0520 - true_positives: 27.0000 - true_negatives: 7096615.0000 - false_positives: 41.0000 - false_negatives: 168941.0000 - val_loss: 3.5106 - val_accuracy: 0.0813 - val_true_positives: 5.0000 - val_true_negatives: 1774118.0000 - val_false_positives: 4.0000 - val_false_negatives: 42236.0000 - lr: 0.0010
# Epoch 4/128
# 1321/1321 [==============================] - 124s 94ms/step - loss: 3.5889 - accuracy: 0.0572 - true_positives: 26.0000 - true_negatives: 7096620.0000 - false_positives: 36.0000 - false_negatives: 168942.0000 - val_loss: 3.5018 - val_accuracy: 0.0875 - val_true_positives: 9.0000 - val_true_negatives: 1774113.0000 - val_false_positives: 9.0000 - val_false_negatives: 42232.0000 - lr: 0.0010
# Epoch 5/128
# 1321/1321 [==============================] - 125s 94ms/step - loss: 3.5772 - accuracy: 0.0582 - true_positives: 31.0000 - true_negatives: 7096619.0000 - false_positives: 37.0000 - false_negatives: 168937.0000 - val_loss: 3.4932 - val_accuracy: 0.0829 - val_true_positives: 13.0000 - val_true_negatives: 1774113.0000 - val_false_positives: 9.0000 - val_false_negatives: 42228.0000 - lr: 0.0010
# Epoch 6/128
# 1321/1321 [==============================] - 124s 94ms/step - loss: 3.5695 - accuracy: 0.0601 - true_positives: 41.0000 - true_negatives: 7096626.0000 - false_positives: 30.0000 - false_negatives: 168927.0000 - val_loss: 3.4675 - val_accuracy: 0.0939 - val_true_positives: 9.0000 - val_true_negatives: 1774112.0000 - val_false_positives: 10.0000 - val_false_negatives: 42232.0000 - lr: 0.0010
# Epoch 7/128
# 1321/1321 [==============================] - 124s 94ms/step - loss: 3.5581 - accuracy: 0.0626 - true_positives: 44.0000 - true_negatives: 7096613.0000 - false_positives: 43.0000 - false_negatives: 168924.0000 - val_loss: 3.4724 - val_accuracy: 0.0905 - val_true_positives: 8.0000 - val_true_negatives: 1774114.0000 - val_false_positives: 8.0000 - val_false_negatives: 42233.0000 - lr: 0.0010
# Epoch 8/128
# 1321/1321 [==============================] - 124s 94ms/step - loss: 3.5507 - accuracy: 0.0635 - true_positives: 35.0000 - true_negatives: 7096613.0000 - false_positives: 43.0000 - false_negatives: 168933.0000 - val_loss: 3.4452 - val_accuracy: 0.1014 - val_true_positives: 7.0000 - val_true_negatives: 1774116.0000 - val_false_positives: 6.0000 - val_false_negatives: 42234.0000 - lr: 0.0010
# Epoch 9/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.5346 - accuracy: 0.0672 - true_positives: 37.0000 - true_negatives: 7096615.0000 - false_positives: 41.0000 - false_negatives: 168931.0000 - val_loss: 3.4181 - val_accuracy: 0.1073 - val_true_positives: 9.0000 - val_true_negatives: 1774120.0000 - val_false_positives: 2.0000 - val_false_negatives: 42232.0000 - lr: 0.0010
# Epoch 10/128
# 1321/1321 [==============================] - 121s 92ms/step - loss: 3.5243 - accuracy: 0.0689 - true_positives: 64.0000 - true_negatives: 7096613.0000 - false_positives: 43.0000 - false_negatives: 168904.0000 - val_loss: 3.4183 - val_accuracy: 0.0961 - val_true_positives: 11.0000 - val_true_negatives: 1774115.0000 - val_false_positives: 7.0000 - val_false_negatives: 42230.0000 - lr: 0.0010
# Epoch 11/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.5193 - accuracy: 0.0705 - true_positives: 57.0000 - true_negatives: 7096600.0000 - false_positives: 56.0000 - false_negatives: 168911.0000 - val_loss: 3.4176 - val_accuracy: 0.0992 - val_true_positives: 11.0000 - val_true_negatives: 1774112.0000 - val_false_positives: 10.0000 - val_false_negatives: 42230.0000 - lr: 0.0010
# Epoch 12/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.5149 - accuracy: 0.0710 - true_positives: 68.0000 - true_negatives: 7096603.0000 - false_positives: 53.0000 - false_negatives: 168900.0000 - val_loss: 3.4180 - val_accuracy: 0.1071 - val_true_positives: 12.0000 - val_true_negatives: 1774115.0000 - val_false_positives: 7.0000 - val_false_negatives: 42229.0000 - lr: 0.0010
# Epoch 13/128
# 1321/1321 [==============================] - 124s 94ms/step - loss: 3.5032 - accuracy: 0.0733 - true_positives: 69.0000 - true_negatives: 7096581.0000 - false_positives: 75.0000 - false_negatives: 168899.0000 - val_loss: 3.3820 - val_accuracy: 0.1170 - val_true_positives: 11.0000 - val_true_negatives: 1774113.0000 - val_false_positives: 9.0000 - val_false_negatives: 42230.0000 - lr: 0.0010
# Epoch 14/128
# 1321/1321 [==============================] - 122s 93ms/step - loss: 3.4963 - accuracy: 0.0759 - true_positives: 69.0000 - true_negatives: 7096590.0000 - false_positives: 66.0000 - false_negatives: 168899.0000 - val_loss: 3.3811 - val_accuracy: 0.1089 - val_true_positives: 12.0000 - val_true_negatives: 1774113.0000 - val_false_positives: 9.0000 - val_false_negatives: 42229.0000 - lr: 0.0010
# Epoch 15/128
# 1321/1321 [==============================] - 123s 93ms/step - loss: 3.4917 - accuracy: 0.0761 - true_positives: 71.0000 - true_negatives: 7096602.0000 - false_positives: 54.0000 - false_negatives: 168897.0000 - val_loss: 3.3968 - val_accuracy: 0.1103 - val_true_positives: 15.0000 - val_true_negatives: 1774116.0000 - val_false_positives: 6.0000 - val_false_negatives: 42226.0000 - lr: 0.0010
# Epoch 16/128
# 1321/1321 [==============================] - 121s 92ms/step - loss: 3.4817 - accuracy: 0.0798 - true_positives: 66.0000 - true_negatives: 7096593.0000 - false_positives: 63.0000 - false_negatives: 168902.0000 - val_loss: 3.3620 - val_accuracy: 0.1179 - val_true_positives: 14.0000 - val_true_negatives: 1774105.0000 - val_false_positives: 17.0000 - val_false_negatives: 42227.0000 - lr: 0.0010
# Epoch 17/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.4790 - accuracy: 0.0807 - true_positives: 92.0000 - true_negatives: 7096593.0000 - false_positives: 63.0000 - false_negatives: 168876.0000 - val_loss: 3.3785 - val_accuracy: 0.1141 - val_true_positives: 13.0000 - val_true_negatives: 1774111.0000 - val_false_positives: 11.0000 - val_false_negatives: 42228.0000 - lr: 0.0010
# Epoch 18/128
# 1321/1321 [==============================] - 121s 91ms/step - loss: 3.4690 - accuracy: 0.0809 - true_positives: 103.0000 - true_negatives: 7096583.0000 - false_positives: 73.0000 - false_negatives: 168865.0000 - val_loss: 3.3642 - val_accuracy: 0.1191 - val_true_positives: 13.0000 - val_true_negatives: 1774116.0000 - val_false_positives: 6.0000 - val_false_negatives: 42228.0000 - lr: 0.0010
# Epoch 19/128
# 1321/1321 [==============================] - 121s 91ms/step - loss: 3.4632 - accuracy: 0.0835 - true_positives: 100.0000 - true_negatives: 7096574.0000 - false_positives: 82.0000 - false_negatives: 168868.0000 - val_loss: 3.3335 - val_accuracy: 0.1264 - val_true_positives: 18.0000 - val_true_negatives: 1774116.0000 - val_false_positives: 6.0000 - val_false_negatives: 42223.0000 - lr: 0.0010
# Epoch 20/128
# 1321/1321 [==============================] - 121s 91ms/step - loss: 3.4583 - accuracy: 0.0830 - true_positives: 102.0000 - true_negatives: 7096561.0000 - false_positives: 95.0000 - false_negatives: 168866.0000 - val_loss: 3.3331 - val_accuracy: 0.1275 - val_true_positives: 20.0000 - val_true_negatives: 1774114.0000 - val_false_positives: 8.0000 - val_false_negatives: 42221.0000 - lr: 0.0010
# Epoch 21/128
# 1321/1321 [==============================] - 121s 92ms/step - loss: 3.4616 - accuracy: 0.0819 - true_positives: 100.0000 - true_negatives: 7096575.0000 - false_positives: 81.0000 - false_negatives: 168868.0000 - val_loss: 3.3303 - val_accuracy: 0.1312 - val_true_positives: 12.0000 - val_true_negatives: 1774118.0000 - val_false_positives: 4.0000 - val_false_negatives: 42229.0000 - lr: 0.0010
# Epoch 22/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.4687 - accuracy: 0.0807 - true_positives: 87.0000 - true_negatives: 7096579.0000 - false_positives: 77.0000 - false_negatives: 168881.0000 - val_loss: 3.3281 - val_accuracy: 0.1277 - val_true_positives: 15.0000 - val_true_negatives: 1774117.0000 - val_false_positives: 5.0000 - val_false_negatives: 42226.0000 - lr: 0.0010
# Epoch 23/128
# 1321/1321 [==============================] - 121s 91ms/step - loss: 3.4661 - accuracy: 0.0805 - true_positives: 81.0000 - true_negatives: 7096591.0000 - false_positives: 65.0000 - false_negatives: 168887.0000 - val_loss: 3.3202 - val_accuracy: 0.1342 - val_true_positives: 13.0000 - val_true_negatives: 1774115.0000 - val_false_positives: 7.0000 - val_false_negatives: 42228.0000 - lr: 0.0010
# Epoch 24/128
# 1321/1321 [==============================] - 123s 93ms/step - loss: 3.4595 - accuracy: 0.0831 - true_positives: 93.0000 - true_negatives: 7096586.0000 - false_positives: 70.0000 - false_negatives: 168875.0000 - val_loss: 3.3144 - val_accuracy: 0.1318 - val_true_positives: 20.0000 - val_true_negatives: 1774112.0000 - val_false_positives: 10.0000 - val_false_negatives: 42221.0000 - lr: 0.0010
# Epoch 25/128
# 1321/1321 [==============================] - 121s 92ms/step - loss: 3.4431 - accuracy: 0.0853 - true_positives: 131.0000 - true_negatives: 7096560.0000 - false_positives: 96.0000 - false_negatives: 168837.0000 - val_loss: 3.3354 - val_accuracy: 0.1247 - val_true_positives: 17.0000 - val_true_negatives: 1774110.0000 - val_false_positives: 12.0000 - val_false_negatives: 42224.0000 - lr: 0.0010
# Epoch 26/128
# 1321/1321 [==============================] - 123s 93ms/step - loss: 3.4419 - accuracy: 0.0844 - true_positives: 126.0000 - true_negatives: 7096554.0000 - false_positives: 102.0000 - false_negatives: 168842.0000 - val_loss: 3.3097 - val_accuracy: 0.1333 - val_true_positives: 14.0000 - val_true_negatives: 1774115.0000 - val_false_positives: 7.0000 - val_false_negatives: 42227.0000 - lr: 0.0010
# Epoch 27/128
# 1321/1321 [==============================] - 124s 93ms/step - loss: 3.4362 - accuracy: 0.0862 - true_positives: 123.0000 - true_negatives: 7096565.0000 - false_positives: 91.0000 - false_negatives: 168845.0000 - val_loss: 3.2989 - val_accuracy: 0.1398 - val_true_positives: 17.0000 - val_true_negatives: 1774114.0000 - val_false_positives: 8.0000 - val_false_negatives: 42224.0000 - lr: 0.0010
# Epoch 28/128
# 1321/1321 [==============================] - 124s 93ms/step - loss: 3.4376 - accuracy: 0.0870 - true_positives: 128.0000 - true_negatives: 7096547.0000 - false_positives: 109.0000 - false_negatives: 168840.0000 - val_loss: 3.2826 - val_accuracy: 0.1444 - val_true_positives: 11.0000 - val_true_negatives: 1774112.0000 - val_false_positives: 10.0000 - val_false_negatives: 42230.0000 - lr: 0.0010
# Epoch 29/128
# 1321/1321 [==============================] - 122s 93ms/step - loss: 3.4339 - accuracy: 0.0882 - true_positives: 148.0000 - true_negatives: 7096548.0000 - false_positives: 108.0000 - false_negatives: 168820.0000 - val_loss: 3.3604 - val_accuracy: 0.1188 - val_true_positives: 19.0000 - val_true_negatives: 1774111.0000 - val_false_positives: 11.0000 - val_false_negatives: 42222.0000 - lr: 0.0010
# Epoch 30/128
# 1321/1321 [==============================] - 121s 91ms/step - loss: 3.4329 - accuracy: 0.0870 - true_positives: 143.0000 - true_negatives: 7096530.0000 - false_positives: 126.0000 - false_negatives: 168825.0000 - val_loss: 3.2987 - val_accuracy: 0.1320 - val_true_positives: 18.0000 - val_true_negatives: 1774113.0000 - val_false_positives: 9.0000 - val_false_negatives: 42223.0000 - lr: 0.0010
# Epoch 31/128
# 1321/1321 [==============================] - 121s 92ms/step - loss: 3.4263 - accuracy: 0.0888 - true_positives: 158.0000 - true_negatives: 7096542.0000 - false_positives: 114.0000 - false_negatives: 168810.0000 - val_loss: 3.2953 - val_accuracy: 0.1417 - val_true_positives: 19.0000 - val_true_negatives: 1774105.0000 - val_false_positives: 17.0000 - val_false_negatives: 42222.0000 - lr: 0.0010
# Epoch 32/128
# 1321/1321 [==============================] - 121s 92ms/step - loss: 3.4201 - accuracy: 0.0905 - true_positives: 173.0000 - true_negatives: 7096540.0000 - false_positives: 116.0000 - false_negatives: 168795.0000 - val_loss: 3.2724 - val_accuracy: 0.1447 - val_true_positives: 20.0000 - val_true_negatives: 1774109.0000 - val_false_positives: 13.0000 - val_false_negatives: 42221.0000 - lr: 0.0010
# Epoch 33/128
# 1321/1321 [==============================] - 121s 91ms/step - loss: 3.4160 - accuracy: 0.0914 - true_positives: 175.0000 - true_negatives: 7096526.0000 - false_positives: 130.0000 - false_negatives: 168793.0000 - val_loss: 3.2693 - val_accuracy: 0.1452 - val_true_positives: 15.0000 - val_true_negatives: 1774109.0000 - val_false_positives: 13.0000 - val_false_negatives: 42226.0000 - lr: 0.0010
# Epoch 34/128
# 1321/1321 [==============================] - 120s 91ms/step - loss: 3.4181 - accuracy: 0.0910 - true_positives: 168.0000 - true_negatives: 7096499.0000 - false_positives: 157.0000 - false_negatives: 168800.0000 - val_loss: 3.3318 - val_accuracy: 0.1208 - val_true_positives: 14.0000 - val_true_negatives: 1774112.0000 - val_false_positives: 10.0000 - val_false_negatives: 42227.0000 - lr: 0.0010
# Epoch 35/128
# 1321/1321 [==============================] - 121s 91ms/step - loss: 3.4206 - accuracy: 0.0908 - true_positives: 170.0000 - true_negatives: 7096518.0000 - false_positives: 138.0000 - false_negatives: 168798.0000 - val_loss: 3.2668 - val_accuracy: 0.1438 - val_true_positives: 19.0000 - val_true_negatives: 1774109.0000 - val_false_positives: 13.0000 - val_false_negatives: 42222.0000 - lr: 0.0010
# Epoch 36/128
# 1321/1321 [==============================] - 121s 92ms/step - loss: 3.4140 - accuracy: 0.0916 - true_positives: 180.0000 - true_negatives: 7096528.0000 - false_positives: 128.0000 - false_negatives: 168788.0000 - val_loss: 3.2588 - val_accuracy: 0.1477 - val_true_positives: 19.0000 - val_true_negatives: 1774112.0000 - val_false_positives: 10.0000 - val_false_negatives: 42222.0000 - lr: 0.0010
# Epoch 37/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.4150 - accuracy: 0.0917 - true_positives: 180.0000 - true_negatives: 7096505.0000 - false_positives: 151.0000 - false_negatives: 168788.0000 - val_loss: 3.3225 - val_accuracy: 0.1316 - val_true_positives: 20.0000 - val_true_negatives: 1774113.0000 - val_false_positives: 9.0000 - val_false_negatives: 42221.0000 - lr: 0.0010
# Epoch 38/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.4184 - accuracy: 0.0899 - true_positives: 176.0000 - true_negatives: 7096529.0000 - false_positives: 127.0000 - false_negatives: 168792.0000 - val_loss: 3.2807 - val_accuracy: 0.1408 - val_true_positives: 12.0000 - val_true_negatives: 1774108.0000 - val_false_positives: 14.0000 - val_false_negatives: 42229.0000 - lr: 0.0010
# Epoch 39/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.4139 - accuracy: 0.0917 - true_positives: 174.0000 - true_negatives: 7096505.0000 - false_positives: 151.0000 - false_negatives: 168794.0000 - val_loss: 3.2948 - val_accuracy: 0.1303 - val_true_positives: 21.0000 - val_true_negatives: 1774110.0000 - val_false_positives: 12.0000 - val_false_negatives: 42220.0000 - lr: 0.0010
# Epoch 40/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.4135 - accuracy: 0.0916 - true_positives: 159.0000 - true_negatives: 7096509.0000 - false_positives: 147.0000 - false_negatives: 168809.0000 - val_loss: 3.2436 - val_accuracy: 0.1551 - val_true_positives: 17.0000 - val_true_negatives: 1774110.0000 - val_false_positives: 12.0000 - val_false_negatives: 42224.0000 - lr: 0.0010
# Epoch 41/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.4156 - accuracy: 0.0914 - true_positives: 205.0000 - true_negatives: 7096521.0000 - false_positives: 135.0000 - false_negatives: 168763.0000 - val_loss: 3.2790 - val_accuracy: 0.1416 - val_true_positives: 15.0000 - val_true_negatives: 1774113.0000 - val_false_positives: 9.0000 - val_false_negatives: 42226.0000 - lr: 0.0010
# Epoch 42/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.4076 - accuracy: 0.0929 - true_positives: 184.0000 - true_negatives: 7096481.0000 - false_positives: 175.0000 - false_negatives: 168784.0000 - val_loss: 3.3350 - val_accuracy: 0.1217 - val_true_positives: 21.0000 - val_true_negatives: 1774113.0000 - val_false_positives: 9.0000 - val_false_negatives: 42220.0000 - lr: 0.0010
# Epoch 43/128
# 1321/1321 [==============================] - 121s 92ms/step - loss: 3.4387 - accuracy: 0.0865 - true_positives: 168.0000 - true_negatives: 7096521.0000 - false_positives: 135.0000 - false_negatives: 168800.0000 - val_loss: 3.3279 - val_accuracy: 0.1190 - val_true_positives: 19.0000 - val_true_negatives: 1774114.0000 - val_false_positives: 8.0000 - val_false_negatives: 42222.0000 - lr: 0.0010
# Epoch 44/128
# 1321/1321 [==============================] - 123s 93ms/step - loss: 3.4226 - accuracy: 0.0887 - true_positives: 177.0000 - true_negatives: 7096534.0000 - false_positives: 122.0000 - false_negatives: 168791.0000 - val_loss: 3.2902 - val_accuracy: 0.1379 - val_true_positives: 15.0000 - val_true_negatives: 1774114.0000 - val_false_positives: 8.0000 - val_false_negatives: 42226.0000 - lr: 0.0010
# Epoch 45/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.4064 - accuracy: 0.0917 - true_positives: 159.0000 - true_negatives: 7096544.0000 - false_positives: 112.0000 - false_negatives: 168809.0000 - val_loss: 3.2461 - val_accuracy: 0.1514 - val_true_positives: 17.0000 - val_true_negatives: 1774110.0000 - val_false_positives: 12.0000 - val_false_negatives: 42224.0000 - lr: 5.0000e-04
# Epoch 46/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.4046 - accuracy: 0.0933 - true_positives: 143.0000 - true_negatives: 7096540.0000 - false_positives: 116.0000 - false_negatives: 168825.0000 - val_loss: 3.2551 - val_accuracy: 0.1453 - val_true_positives: 20.0000 - val_true_negatives: 1774111.0000 - val_false_positives: 11.0000 - val_false_negatives: 42221.0000 - lr: 5.0000e-04
# Epoch 47/128
# 1321/1321 [==============================] - 121s 92ms/step - loss: 3.3928 - accuracy: 0.0955 - true_positives: 213.0000 - true_negatives: 7096535.0000 - false_positives: 121.0000 - false_negatives: 168755.0000 - val_loss: 3.2260 - val_accuracy: 0.1610 - val_true_positives: 22.0000 - val_true_negatives: 1774109.0000 - val_false_positives: 13.0000 - val_false_negatives: 42219.0000 - lr: 5.0000e-04
# Epoch 48/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.3855 - accuracy: 0.0980 - true_positives: 226.0000 - true_negatives: 7096512.0000 - false_positives: 144.0000 - false_negatives: 168742.0000 - val_loss: 3.2662 - val_accuracy: 0.1488 - val_true_positives: 19.0000 - val_true_negatives: 1774109.0000 - val_false_positives: 13.0000 - val_false_negatives: 42222.0000 - lr: 5.0000e-04
# Epoch 49/128
# 1321/1321 [==============================] - 121s 92ms/step - loss: 3.4239 - accuracy: 0.0872 - true_positives: 150.0000 - true_negatives: 7096591.0000 - false_positives: 65.0000 - false_negatives: 168818.0000 - val_loss: 3.2662 - val_accuracy: 0.1429 - val_true_positives: 17.0000 - val_true_negatives: 1774113.0000 - val_false_positives: 9.0000 - val_false_negatives: 42224.0000 - lr: 5.0000e-04
# Epoch 50/128
# 1321/1321 [==============================] - 121s 91ms/step - loss: 3.4218 - accuracy: 0.0876 - true_positives: 152.0000 - true_negatives: 7096590.0000 - false_positives: 66.0000 - false_negatives: 168816.0000 - val_loss: 3.3009 - val_accuracy: 0.1347 - val_true_positives: 23.0000 - val_true_negatives: 1774108.0000 - val_false_positives: 14.0000 - val_false_negatives: 42218.0000 - lr: 5.0000e-04
# Epoch 51/128
# 1321/1321 [==============================] - 121s 91ms/step - loss: 3.4187 - accuracy: 0.0892 - true_positives: 182.0000 - true_negatives: 7096571.0000 - false_positives: 85.0000 - false_negatives: 168786.0000 - val_loss: 3.2614 - val_accuracy: 0.1467 - val_true_positives: 26.0000 - val_true_negatives: 1774106.0000 - val_false_positives: 16.0000 - val_false_negatives: 42215.0000 - lr: 5.0000e-04
# Epoch 52/128
# 1321/1321 [==============================] - 122s 92ms/step - loss: 3.4097 - accuracy: 0.0917 - true_positives: 171.0000 - true_negatives: 7096580.0000 - false_positives: 76.0000 - false_negatives: 168797.0000 - val_loss: 3.2493 - val_accuracy: 0.1503 - val_true_positives: 21.0000 - val_true_negatives: 1774107.0000 - val_false_positives: 15.0000 - val_false_negatives: 42220.0000 - lr: 2.5000e-04
# Epoch 53/128
# 1321/1321 [==============================] - 121s 91ms/step - loss: 3.4075 - accuracy: 0.0917 - true_positives: 152.0000 - true_negatives: 7096579.0000 - false_positives: 77.0000 - false_negatives: 168816.0000 - val_loss: 3.2515 - val_accuracy: 0.1501 - val_true_positives: 27.0000 - val_true_negatives: 1774103.0000 - val_false_positives: 19.0000 - val_false_negatives: 42214.0000 - lr: 2.5000e-04
# Epoch 54/128
# 1321/1321 [==============================] - 121s 91ms/step - loss: 3.4099 - accuracy: 0.0909 - true_positives: 147.0000 - true_negatives: 7096571.0000 - false_positives: 85.0000 - false_negatives: 168821.0000 - val_loss: 3.2559 - val_accuracy: 0.1485 - val_true_positives: 20.0000 - val_true_negatives: 1774105.0000 - val_false_positives: 17.0000 - val_false_negatives: 42221.0000 - lr: 2.5000e-04
# Epoch 55/128
# 1321/1321 [==============================] - 121s 92ms/step - loss: 3.4069 - accuracy: 0.0920 - true_positives: 161.0000 - true_negatives: 7096576.0000 - false_positives: 80.0000 - false_negatives: 168807.0000 - val_loss: 3.2595 - val_accuracy: 0.1465 - val_true_positives: 22.0000 - val_true_negatives: 1774107.0000 - val_false_positives: 15.0000 - val_false_negatives: 42219.0000 - lr: 2.5000e-04

# %%
import pandas as pd

HISTORY_CSV = pd.DataFrame(history.history)
HISTORY_CSV.to_csv("/kaggle/working/history_NASNet.csv")


model.save("/kaggle/working/NASNet-Adversarial-GTSRB.h5")
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from sklearn.metrics import confusion_matrix

# Generate predictions
y_pred_classes = np.array([])
y_true = np.array([])
class_names = os.listdir('/kaggle/input/adversarial-gtsrb-data/Adversarial-GTSRB-Data/')

for x, y in val_data:
    y_pred_classes = np.concatenate([y_pred_classes, np.argmax(model.predict(x, verbose=0), axis=1)])
    y_true = np.concatenate([y_true, np.argmax(y.numpy(), axis=-1)])
    
# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(20, 20))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.PuRd)
plt.title('Confusion Matrix')
plt.colorbar(shrink=0.5)
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=90)
plt.yticks(tick_marks, class_names)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# # Plot the text on each cell
# thresh = cm_normalized.max() / 2.
# for i in range(cm.shape[0]):
#     for j in range(cm.shape[1]): 
#         plt.text(j, i, format(cm[i, j], '.2f'),
#                  horizontalalignment="center",
#                  color="white" if cm_normalized[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show('Predicted label')
plt.show()

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import numpy as np
import pandas as pd

FP = cm.sum(axis=0) - np.diag(cm) 
FN = cm.sum(axis=1) - np.diag(cm)
TP = np.diag(cm)
TN = cm.sum() - (FP + FN + TP)

accuracy = (TP + TN) / (TP + TN + FP + FN)
error_rate = 1 - accuracy

error_rate_dict = {class_names[i]: error_rate[i]*100 for i in range(len(error_rate))}
df = pd.DataFrame(list(error_rate_dict.values()), columns=['Error Rate'])
df.index = error_rate_dict.keys()

df
# Out:
#                                Error Rate
# Speed limit (50kmh)              7.393291
# Go straight or right             4.730002
# Speed limit (100kmh)             3.548685
# Slippery road                    2.419450
# Veh _ 3.5 tons prohibited        3.042068
# Wild animals crossing            2.982884
# No passing veh over 3.5 tons     3.248029
# Bumpy road                       2.002793
# Go straight or left              2.885822
# Bicycles crossing                2.137733
# Speed limit (80kmh)             10.096825
# Priority road                    2.012263
# Beware of icesnow                4.500367
# Road narrows on the right        9.294288
# Right-of-way at intersection     3.193580
# Speed limit (70kmh)              3.006558
# Traffic signals                  6.950593
# Roundabout mandatory             2.831372
# Pedestrians                      3.129661
# Road work                        6.294832
# Keep right                       2.246632
# Speed limit (20kmh)              5.075637
# Keep left                        3.974811
# Turn left ahead                  4.318080
# Children crossing                2.083284
# No passing                       4.692124
# Stop                             2.208755
# Dangerous curve right            2.589901
# Double curve                     3.200682
# Yield                            5.658010
# Speed limit (60kmh)              2.739045
# Dangerous curve left             4.680287
# End speed + passing limits       5.130087
# End of no passing                2.507043
# General caution                  4.623470
# No vehicles                      3.458725
# End of speed limit (80kmh)       3.195947
# Speed limit (30kmh)              2.381572
# No entry                         2.471532
# Turn right ahead                 2.961578
# Speed limit (120kmh)             3.075211
# End no passing veh _ 3.5 tons    4.580857
# Ahead only                       4.249426

# %%
misclassification_rate = 1 - accuracy_score(y_pred_classes, y_true)

# Calculate Sensitivity (True Positive Rate / Recall)
sensitivity = TP / (TP + FN)

# Calculate Specificity
specificity = TN / (TN + FP)

print(f"\nMisclassification Rate: {misclassification_rate}")
# Out:
# Misclassification Rate: 0.8390189626192561

# %%
sensitivity = sensitivity*100

# Create a bar chart
plt.figure(figsize=(8, 15))
plt.barh(class_names, sensitivity, color='lightgreen')
plt.xlabel('Sensitivity (%)')
plt.ylabel('Classes')
plt.title('Sensitivity')
plt.gca().invert_yaxis()  # Reverse the order of classes for better readability
plt.xlim(0, 105)  # Adjust x-axis limits
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()

# Display the sensitivities on top of the bars
for i, Sensitivity in enumerate(sensitivity):
    plt.text(Sensitivity + 2, i, f'{Sensitivity}%', va='center', fontsize=10)

plt.show()

# %%
metrics = list(history.history.keys())

for metric in metrics:
    if metric.startswith('val')==False and metric!='lr':
        plt.figure(figsize=(6, 4))
        plt.plot(history.history[metric])
        plt.plot(history.history['val_'+metric])
        plt.title('Model '+metric)
        plt.ylabel(metric)
        plt.xlabel('Epoch')
        if metric.endswith('loss'):
            plt.legend(['Train', 'Validation'], loc='upper right')
        else:
            plt.legend(['Train', 'Validation'], loc='lower right')

plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

y_true_classes = y_true
num_classes = 43

# Plot ROC curve for each class (one-vs-all)
n_classes = num_classes
y_true_bin = label_binarize(y_true_classes, classes=np.arange(n_classes))
y_score = model.predict(val_data)

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves
plt.figure(figsize=(16, 25))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'ROC curve (class {i}, area = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 331/331 [==============================] - 28s 67ms/step
