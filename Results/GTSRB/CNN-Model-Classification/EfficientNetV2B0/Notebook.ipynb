# %% [markdown]
# # **ResNet50 - Post GAN**

# %%
import numpy as np
import tensorflow as tf
import os
import matplotlib.pyplot as plt
from tensorflow.keras import layers as L
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# DataLoader
train_data = tf.keras.utils.image_dataset_from_directory(
    '/kaggle/input/adversarial-gtsrb-data/Adversarial-GTSRB-Data',
    batch_size=128,
    image_size=(32, 32),
    label_mode="categorical",
    labels = "inferred",
    validation_split=0.2,
    subset='training',
    seed=42,
)

val_data = tf.keras.utils.image_dataset_from_directory(
    '/kaggle/input/adversarial-gtsrb-data/Adversarial-GTSRB-Data',
    batch_size=128,
    label_mode="categorical",
    labels = "inferred",
    image_size=(32, 32),
    validation_split=0.2,
    subset='validation',
    seed=42,
)
# Out:
# Found 211209 files belonging to 43 classes.
# Using 168968 files for training.
# Found 211209 files belonging to 43 classes.
# Using 42241 files for validation.

# %%
train_data.as_numpy_iterator().__next__()[0].shape
# Out:
# (128, 32, 32, 3)

# %%
train_data.as_numpy_iterator().__next__()[1].shape
# Out:
# (128, 43)

# %%
# Create custom F1 Score Metrics

from keras import backend as K

def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    
    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

# %%
steps_per_epoch = len(train_data)
EPOCHS = 128

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=4, min_lr=0.000001)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", # watch the val loss metric
                                                  patience=8,# if val loss decreases for 8 epochs in a row, stop training
                                                  restore_best_weights = True)

# %%
# Model

def create_model(shape=(32, 32, 3)):
    base_model = tf.keras.applications.efficientnet_v2.EfficientNetV2B0(
        include_top = False,
        input_shape = shape,
        weights = "imagenet",
    )
    
    base_model.trainable = False
    for layer in base_model.layers[-7:]:
#         print(layer)
        layer.trainable = True
        
    x = base_model.output
    x = L.Flatten(name="flatten")(x)
    x = L.Dense(512, activation="relu", name="Dense-1")(x)
    x = L.Dropout(0.4, name="Final-Dropout")(x)
    x = L.Dense(43, activation="softmax", name="Output-layer")(x)
    
    model = tf.keras.models.Model(base_model.input, x, name="EfficientNetV2B0")
    model.compile(
        loss="categorical_crossentropy",
        optimizer="Adam",
        metrics = ["accuracy",tf.keras.metrics.AUC(name="auc"),
                               tf.keras.metrics.Recall(name="recall"),
                               tf.keras.metrics.Precision(name="precision"),
                              f1_score]
    )
    
    return model

# %%
model = create_model()

# Fit the model
history = model.fit(
    train_data,
    epochs = EPOCHS,
    steps_per_epoch = steps_per_epoch,
    validation_data = val_data,
    validation_steps = len(val_data),
    callbacks = [reduce_lr, early_stopping],
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 [==============================] - 0s 0us/step
# Epoch 1/128
# 2023-12-10 16:45:38.075634: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inEfficientNetV2B0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1321/1321 [==============================] - 176s 122ms/step - loss: 1.3786 - accuracy: 0.5868 - auc: 0.9664 - recall: 0.4566 - precision: 0.7979 - f1_score: 0.5678 - val_loss: 0.8307 - val_accuracy: 0.7367 - val_auc: 0.9870 - val_recall: 0.6428 - val_precision: 0.8603 - val_f1_score: 0.7362 - lr: 0.0010
# Epoch 2/128
# 1321/1321 [==============================] - 55s 41ms/step - loss: 0.9118 - accuracy: 0.7145 - auc: 0.9836 - recall: 0.6238 - precision: 0.8377 - f1_score: 0.7145 - val_loss: 0.6831 - val_accuracy: 0.7833 - val_auc: 0.9894 - val_recall: 0.7197 - val_precision: 0.8741 - val_f1_score: 0.7897 - lr: 0.0010
# Epoch 3/128
# 1321/1321 [==============================] - 54s 41ms/step - loss: 0.7776 - accuracy: 0.7545 - auc: 0.9871 - recall: 0.6822 - precision: 0.8552 - f1_score: 0.7583 - val_loss: 0.5709 - val_accuracy: 0.8189 - val_auc: 0.9925 - val_recall: 0.7605 - val_precision: 0.8926 - val_f1_score: 0.8215 - lr: 0.0010
# Epoch 4/128
# 1321/1321 [==============================] - 50s 37ms/step - loss: 0.6985 - accuracy: 0.7784 - auc: 0.9890 - recall: 0.7146 - precision: 0.8652 - f1_score: 0.7823 - val_loss: 0.5374 - val_accuracy: 0.8306 - val_auc: 0.9927 - val_recall: 0.7783 - val_precision: 0.8972 - val_f1_score: 0.8308 - lr: 0.0010
# Epoch 5/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.6404 - accuracy: 0.7958 - auc: 0.9902 - recall: 0.7395 - precision: 0.8726 - f1_score: 0.8000 - val_loss: 0.5220 - val_accuracy: 0.8373 - val_auc: 0.9918 - val_recall: 0.7963 - val_precision: 0.8944 - val_f1_score: 0.8428 - lr: 0.0010
# Epoch 6/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.5971 - accuracy: 0.8090 - auc: 0.9911 - recall: 0.7577 - precision: 0.8788 - f1_score: 0.8135 - val_loss: 0.4952 - val_accuracy: 0.8452 - val_auc: 0.9925 - val_recall: 0.8055 - val_precision: 0.8989 - val_f1_score: 0.8499 - lr: 0.0010
# Epoch 7/128
# 1321/1321 [==============================] - 47s 36ms/step - loss: 0.5653 - accuracy: 0.8185 - auc: 0.9919 - recall: 0.7711 - precision: 0.8830 - f1_score: 0.8231 - val_loss: 0.4636 - val_accuracy: 0.8543 - val_auc: 0.9926 - val_recall: 0.8215 - val_precision: 0.9034 - val_f1_score: 0.8577 - lr: 0.0010
# Epoch 8/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.5317 - accuracy: 0.8285 - auc: 0.9926 - recall: 0.7848 - precision: 0.8879 - f1_score: 0.8330 - val_loss: 0.4496 - val_accuracy: 0.8622 - val_auc: 0.9927 - val_recall: 0.8310 - val_precision: 0.9074 - val_f1_score: 0.8678 - lr: 0.0010
# Epoch 9/128
# 1321/1321 [==============================] - 48s 36ms/step - loss: 0.5144 - accuracy: 0.8350 - auc: 0.9927 - recall: 0.7934 - precision: 0.8912 - f1_score: 0.8391 - val_loss: 0.4359 - val_accuracy: 0.8648 - val_auc: 0.9929 - val_recall: 0.8349 - val_precision: 0.9093 - val_f1_score: 0.8707 - lr: 0.0010
# Epoch 10/128
# 1321/1321 [==============================] - 50s 38ms/step - loss: 0.4888 - accuracy: 0.8430 - auc: 0.9931 - recall: 0.8041 - precision: 0.8949 - f1_score: 0.8468 - val_loss: 0.4289 - val_accuracy: 0.8675 - val_auc: 0.9926 - val_recall: 0.8412 - val_precision: 0.9088 - val_f1_score: 0.8710 - lr: 0.0010
# Epoch 11/128
# 1321/1321 [==============================] - 50s 38ms/step - loss: 0.4726 - accuracy: 0.8485 - auc: 0.9935 - recall: 0.8114 - precision: 0.8973 - f1_score: 0.8520 - val_loss: 0.4228 - val_accuracy: 0.8713 - val_auc: 0.9928 - val_recall: 0.8418 - val_precision: 0.9129 - val_f1_score: 0.8761 - lr: 0.0010
# Epoch 12/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.4575 - accuracy: 0.8524 - auc: 0.9938 - recall: 0.8175 - precision: 0.8997 - f1_score: 0.8564 - val_loss: 0.4139 - val_accuracy: 0.8735 - val_auc: 0.9928 - val_recall: 0.8494 - val_precision: 0.9121 - val_f1_score: 0.8799 - lr: 0.0010
# Epoch 13/128
# 1321/1321 [==============================] - 55s 41ms/step - loss: 0.4436 - accuracy: 0.8579 - auc: 0.9938 - recall: 0.8244 - precision: 0.9026 - f1_score: 0.8615 - val_loss: 0.4146 - val_accuracy: 0.8754 - val_auc: 0.9921 - val_recall: 0.8514 - val_precision: 0.9094 - val_f1_score: 0.8797 - lr: 0.0010
# Epoch 14/128
# 1321/1321 [==============================] - 57s 43ms/step - loss: 0.4298 - accuracy: 0.8606 - auc: 0.9942 - recall: 0.8279 - precision: 0.9038 - f1_score: 0.8638 - val_loss: 0.4080 - val_accuracy: 0.8770 - val_auc: 0.9924 - val_recall: 0.8554 - val_precision: 0.9110 - val_f1_score: 0.8826 - lr: 0.0010
# Epoch 15/128
# 1321/1321 [==============================] - 53s 40ms/step - loss: 0.4145 - accuracy: 0.8670 - auc: 0.9944 - recall: 0.8368 - precision: 0.9081 - f1_score: 0.8707 - val_loss: 0.4010 - val_accuracy: 0.8798 - val_auc: 0.9923 - val_recall: 0.8592 - val_precision: 0.9129 - val_f1_score: 0.8855 - lr: 0.0010
# Epoch 16/128
# 1321/1321 [==============================] - 50s 38ms/step - loss: 0.4102 - accuracy: 0.8682 - auc: 0.9942 - recall: 0.8382 - precision: 0.9080 - f1_score: 0.8712 - val_loss: 0.3909 - val_accuracy: 0.8813 - val_auc: 0.9930 - val_recall: 0.8592 - val_precision: 0.9154 - val_f1_score: 0.8867 - lr: 0.0010
# Epoch 17/128
# 1321/1321 [==============================] - 52s 39ms/step - loss: 0.4005 - accuracy: 0.8710 - auc: 0.9945 - recall: 0.8419 - precision: 0.9097 - f1_score: 0.8743 - val_loss: 0.4025 - val_accuracy: 0.8830 - val_auc: 0.9918 - val_recall: 0.8625 - val_precision: 0.9143 - val_f1_score: 0.8879 - lr: 0.0010
# Epoch 18/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.3918 - accuracy: 0.8733 - auc: 0.9948 - recall: 0.8452 - precision: 0.9108 - f1_score: 0.8762 - val_loss: 0.4059 - val_accuracy: 0.8819 - val_auc: 0.9918 - val_recall: 0.8614 - val_precision: 0.9128 - val_f1_score: 0.8866 - lr: 0.0010
# Epoch 19/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.3863 - accuracy: 0.8762 - auc: 0.9946 - recall: 0.8492 - precision: 0.9129 - f1_score: 0.8795 - val_loss: 0.3852 - val_accuracy: 0.8869 - val_auc: 0.9922 - val_recall: 0.8675 - val_precision: 0.9168 - val_f1_score: 0.8917 - lr: 0.0010
# Epoch 20/128
# 1321/1321 [==============================] - 50s 37ms/step - loss: 0.3772 - accuracy: 0.8790 - auc: 0.9947 - recall: 0.8532 - precision: 0.9143 - f1_score: 0.8825 - val_loss: 0.3919 - val_accuracy: 0.8866 - val_auc: 0.9920 - val_recall: 0.8687 - val_precision: 0.9148 - val_f1_score: 0.8913 - lr: 0.0010
# Epoch 21/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.3687 - accuracy: 0.8809 - auc: 0.9950 - recall: 0.8553 - precision: 0.9152 - f1_score: 0.8841 - val_loss: 0.4015 - val_accuracy: 0.8838 - val_auc: 0.9912 - val_recall: 0.8652 - val_precision: 0.9119 - val_f1_score: 0.8882 - lr: 0.0010
# Epoch 22/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.3625 - accuracy: 0.8833 - auc: 0.9950 - recall: 0.8588 - precision: 0.9165 - f1_score: 0.8865 - val_loss: 0.3818 - val_accuracy: 0.8889 - val_auc: 0.9920 - val_recall: 0.8695 - val_precision: 0.9181 - val_f1_score: 0.8934 - lr: 0.0010
# Epoch 23/128
# 1321/1321 [==============================] - 48s 36ms/step - loss: 0.3592 - accuracy: 0.8850 - auc: 0.9949 - recall: 0.8613 - precision: 0.9171 - f1_score: 0.8880 - val_loss: 0.3811 - val_accuracy: 0.8895 - val_auc: 0.9922 - val_recall: 0.8717 - val_precision: 0.9178 - val_f1_score: 0.8944 - lr: 0.0010
# Epoch 24/128
# 1321/1321 [==============================] - 48s 36ms/step - loss: 0.3526 - accuracy: 0.8871 - auc: 0.9949 - recall: 0.8638 - precision: 0.9190 - f1_score: 0.8904 - val_loss: 0.3910 - val_accuracy: 0.8888 - val_auc: 0.9910 - val_recall: 0.8739 - val_precision: 0.9141 - val_f1_score: 0.8938 - lr: 0.0010
# Epoch 25/128
# 1321/1321 [==============================] - 51s 38ms/step - loss: 0.3454 - accuracy: 0.8899 - auc: 0.9952 - recall: 0.8667 - precision: 0.9202 - f1_score: 0.8924 - val_loss: 0.3907 - val_accuracy: 0.8889 - val_auc: 0.9911 - val_recall: 0.8725 - val_precision: 0.9149 - val_f1_score: 0.8934 - lr: 0.0010
# Epoch 26/128
# 1321/1321 [==============================] - 48s 36ms/step - loss: 0.3472 - accuracy: 0.8891 - auc: 0.9951 - recall: 0.8668 - precision: 0.9207 - f1_score: 0.8926 - val_loss: 0.3812 - val_accuracy: 0.8924 - val_auc: 0.9914 - val_recall: 0.8767 - val_precision: 0.9172 - val_f1_score: 0.8937 - lr: 0.0010
# Epoch 27/128
# 1321/1321 [==============================] - 53s 40ms/step - loss: 0.3376 - accuracy: 0.8913 - auc: 0.9954 - recall: 0.8698 - precision: 0.9210 - f1_score: 0.8944 - val_loss: 0.3871 - val_accuracy: 0.8933 - val_auc: 0.9907 - val_recall: 0.8791 - val_precision: 0.9169 - val_f1_score: 0.8949 - lr: 0.0010
# Epoch 28/128
# 1321/1321 [==============================] - 53s 40ms/step - loss: 0.2895 - accuracy: 0.9068 - auc: 0.9964 - recall: 0.8874 - precision: 0.9327 - f1_score: 0.9090 - val_loss: 0.3555 - val_accuracy: 0.9007 - val_auc: 0.9916 - val_recall: 0.8886 - val_precision: 0.9218 - val_f1_score: 0.9051 - lr: 5.0000e-04
# Epoch 29/128
# 1321/1321 [==============================] - 48s 36ms/step - loss: 0.2620 - accuracy: 0.9151 - auc: 0.9969 - recall: 0.8979 - precision: 0.9388 - f1_score: 0.9178 - val_loss: 0.3490 - val_accuracy: 0.9037 - val_auc: 0.9918 - val_recall: 0.8902 - val_precision: 0.9240 - val_f1_score: 0.9070 - lr: 5.0000e-04
# Epoch 30/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.2515 - accuracy: 0.9183 - auc: 0.9969 - recall: 0.9011 - precision: 0.9400 - f1_score: 0.9200 - val_loss: 0.3528 - val_accuracy: 0.9045 - val_auc: 0.9914 - val_recall: 0.8914 - val_precision: 0.9237 - val_f1_score: 0.9075 - lr: 5.0000e-04
# Epoch 31/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.2477 - accuracy: 0.9206 - auc: 0.9970 - recall: 0.9044 - precision: 0.9413 - f1_score: 0.9223 - val_loss: 0.3562 - val_accuracy: 0.9032 - val_auc: 0.9911 - val_recall: 0.8923 - val_precision: 0.9219 - val_f1_score: 0.9070 - lr: 5.0000e-04
# Epoch 32/128
# 1321/1321 [==============================] - 48s 36ms/step - loss: 0.2430 - accuracy: 0.9220 - auc: 0.9970 - recall: 0.9064 - precision: 0.9425 - f1_score: 0.9239 - val_loss: 0.3523 - val_accuracy: 0.9043 - val_auc: 0.9911 - val_recall: 0.8932 - val_precision: 0.9227 - val_f1_score: 0.9080 - lr: 5.0000e-04
# Epoch 33/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.2416 - accuracy: 0.9228 - auc: 0.9970 - recall: 0.9073 - precision: 0.9429 - f1_score: 0.9245 - val_loss: 0.3507 - val_accuracy: 0.9055 - val_auc: 0.9912 - val_recall: 0.8951 - val_precision: 0.9248 - val_f1_score: 0.9069 - lr: 5.0000e-04
# Epoch 34/128
# 1321/1321 [==============================] - 48s 36ms/step - loss: 0.2180 - accuracy: 0.9294 - auc: 0.9975 - recall: 0.9151 - precision: 0.9481 - f1_score: 0.9310 - val_loss: 0.3419 - val_accuracy: 0.9086 - val_auc: 0.9912 - val_recall: 0.8997 - val_precision: 0.9260 - val_f1_score: 0.9129 - lr: 2.5000e-04
# Epoch 35/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.2097 - accuracy: 0.9324 - auc: 0.9976 - recall: 0.9187 - precision: 0.9499 - f1_score: 0.9336 - val_loss: 0.3330 - val_accuracy: 0.9087 - val_auc: 0.9919 - val_recall: 0.8982 - val_precision: 0.9281 - val_f1_score: 0.9131 - lr: 2.5000e-04
# Epoch 36/128
# 1321/1321 [==============================] - 52s 39ms/step - loss: 0.2051 - accuracy: 0.9345 - auc: 0.9976 - recall: 0.9214 - precision: 0.9521 - f1_score: 0.9364 - val_loss: 0.3331 - val_accuracy: 0.9092 - val_auc: 0.9919 - val_recall: 0.8990 - val_precision: 0.9268 - val_f1_score: 0.9129 - lr: 2.5000e-04
# Epoch 37/128
# 1321/1321 [==============================] - 58s 44ms/step - loss: 0.1986 - accuracy: 0.9361 - auc: 0.9978 - recall: 0.9226 - precision: 0.9533 - f1_score: 0.9374 - val_loss: 0.3326 - val_accuracy: 0.9109 - val_auc: 0.9916 - val_recall: 0.9008 - val_precision: 0.9272 - val_f1_score: 0.9140 - lr: 2.5000e-04
# Epoch 38/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.1939 - accuracy: 0.9377 - auc: 0.9978 - recall: 0.9250 - precision: 0.9541 - f1_score: 0.9389 - val_loss: 0.3347 - val_accuracy: 0.9110 - val_auc: 0.9914 - val_recall: 0.9016 - val_precision: 0.9272 - val_f1_score: 0.9144 - lr: 2.5000e-04
# Epoch 39/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.1931 - accuracy: 0.9385 - auc: 0.9979 - recall: 0.9260 - precision: 0.9542 - f1_score: 0.9397 - val_loss: 0.3334 - val_accuracy: 0.9105 - val_auc: 0.9914 - val_recall: 0.9017 - val_precision: 0.9262 - val_f1_score: 0.9140 - lr: 2.5000e-04
# Epoch 40/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.1900 - accuracy: 0.9383 - auc: 0.9981 - recall: 0.9259 - precision: 0.9541 - f1_score: 0.9395 - val_loss: 0.3345 - val_accuracy: 0.9111 - val_auc: 0.9914 - val_recall: 0.9025 - val_precision: 0.9272 - val_f1_score: 0.9149 - lr: 2.5000e-04
# Epoch 41/128
# 1321/1321 [==============================] - 47s 36ms/step - loss: 0.1888 - accuracy: 0.9393 - auc: 0.9978 - recall: 0.9271 - precision: 0.9549 - f1_score: 0.9405 - val_loss: 0.3360 - val_accuracy: 0.9111 - val_auc: 0.9914 - val_recall: 0.9014 - val_precision: 0.9269 - val_f1_score: 0.9142 - lr: 2.5000e-04
# Epoch 42/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.1786 - accuracy: 0.9432 - auc: 0.9980 - recall: 0.9316 - precision: 0.9577 - f1_score: 0.9441 - val_loss: 0.3268 - val_accuracy: 0.9111 - val_auc: 0.9920 - val_recall: 0.9023 - val_precision: 0.9282 - val_f1_score: 0.9153 - lr: 1.2500e-04
# Epoch 43/128
# 1321/1321 [==============================] - 52s 39ms/step - loss: 0.1761 - accuracy: 0.9435 - auc: 0.9982 - recall: 0.9320 - precision: 0.9579 - f1_score: 0.9444 - val_loss: 0.3336 - val_accuracy: 0.9125 - val_auc: 0.9912 - val_recall: 0.9040 - val_precision: 0.9281 - val_f1_score: 0.9161 - lr: 1.2500e-04
# Epoch 44/128
# 1321/1321 [==============================] - 48s 36ms/step - loss: 0.1741 - accuracy: 0.9442 - auc: 0.9982 - recall: 0.9330 - precision: 0.9588 - f1_score: 0.9457 - val_loss: 0.3251 - val_accuracy: 0.9130 - val_auc: 0.9916 - val_recall: 0.9042 - val_precision: 0.9279 - val_f1_score: 0.9161 - lr: 1.2500e-04
# Epoch 45/128
# 1321/1321 [==============================] - 50s 38ms/step - loss: 0.1721 - accuracy: 0.9440 - auc: 0.9982 - recall: 0.9328 - precision: 0.9590 - f1_score: 0.9453 - val_loss: 0.3250 - val_accuracy: 0.9141 - val_auc: 0.9916 - val_recall: 0.9058 - val_precision: 0.9290 - val_f1_score: 0.9175 - lr: 1.2500e-04
# Epoch 46/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.1672 - accuracy: 0.9465 - auc: 0.9982 - recall: 0.9352 - precision: 0.9604 - f1_score: 0.9474 - val_loss: 0.3293 - val_accuracy: 0.9135 - val_auc: 0.9912 - val_recall: 0.9056 - val_precision: 0.9273 - val_f1_score: 0.9165 - lr: 1.2500e-04
# Epoch 47/128
# 1321/1321 [==============================] - 47s 36ms/step - loss: 0.1668 - accuracy: 0.9467 - auc: 0.9982 - recall: 0.9358 - precision: 0.9606 - f1_score: 0.9477 - val_loss: 0.3326 - val_accuracy: 0.9129 - val_auc: 0.9911 - val_recall: 0.9052 - val_precision: 0.9273 - val_f1_score: 0.9164 - lr: 1.2500e-04
# Epoch 48/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.1649 - accuracy: 0.9466 - auc: 0.9983 - recall: 0.9363 - precision: 0.9603 - f1_score: 0.9481 - val_loss: 0.3264 - val_accuracy: 0.9141 - val_auc: 0.9914 - val_recall: 0.9064 - val_precision: 0.9282 - val_f1_score: 0.9174 - lr: 1.2500e-04
# Epoch 49/128
# 1321/1321 [==============================] - 52s 39ms/step - loss: 0.1660 - accuracy: 0.9466 - auc: 0.9982 - recall: 0.9360 - precision: 0.9601 - f1_score: 0.9476 - val_loss: 0.3257 - val_accuracy: 0.9143 - val_auc: 0.9915 - val_recall: 0.9071 - val_precision: 0.9288 - val_f1_score: 0.9180 - lr: 1.2500e-04
# Epoch 50/128
# 1321/1321 [==============================] - 54s 41ms/step - loss: 0.1631 - accuracy: 0.9485 - auc: 0.9982 - recall: 0.9380 - precision: 0.9615 - f1_score: 0.9496 - val_loss: 0.3256 - val_accuracy: 0.9154 - val_auc: 0.9912 - val_recall: 0.9078 - val_precision: 0.9290 - val_f1_score: 0.9185 - lr: 6.2500e-05
# Epoch 51/128
# 1321/1321 [==============================] - 56s 42ms/step - loss: 0.1610 - accuracy: 0.9482 - auc: 0.9983 - recall: 0.9380 - precision: 0.9618 - f1_score: 0.9496 - val_loss: 0.3242 - val_accuracy: 0.9152 - val_auc: 0.9917 - val_recall: 0.9072 - val_precision: 0.9289 - val_f1_score: 0.9181 - lr: 6.2500e-05
# Epoch 52/128
# 1321/1321 [==============================] - 58s 43ms/step - loss: 0.1589 - accuracy: 0.9484 - auc: 0.9983 - recall: 0.9387 - precision: 0.9615 - f1_score: 0.9496 - val_loss: 0.3204 - val_accuracy: 0.9152 - val_auc: 0.9917 - val_recall: 0.9070 - val_precision: 0.9292 - val_f1_score: 0.9182 - lr: 6.2500e-05
# Epoch 53/128
# 1321/1321 [==============================] - 54s 41ms/step - loss: 0.1574 - accuracy: 0.9494 - auc: 0.9984 - recall: 0.9394 - precision: 0.9620 - f1_score: 0.9504 - val_loss: 0.3173 - val_accuracy: 0.9151 - val_auc: 0.9920 - val_recall: 0.9068 - val_precision: 0.9303 - val_f1_score: 0.9156 - lr: 6.2500e-05
# Epoch 54/128
# 1321/1321 [==============================] - 50s 38ms/step - loss: 0.1557 - accuracy: 0.9501 - auc: 0.9984 - recall: 0.9406 - precision: 0.9623 - f1_score: 0.9511 - val_loss: 0.3240 - val_accuracy: 0.9146 - val_auc: 0.9916 - val_recall: 0.9067 - val_precision: 0.9290 - val_f1_score: 0.9179 - lr: 6.2500e-05
# Epoch 55/128
# 1321/1321 [==============================] - 48s 36ms/step - loss: 0.1544 - accuracy: 0.9505 - auc: 0.9984 - recall: 0.9406 - precision: 0.9625 - f1_score: 0.9511 - val_loss: 0.3264 - val_accuracy: 0.9161 - val_auc: 0.9912 - val_recall: 0.9085 - val_precision: 0.9289 - val_f1_score: 0.9158 - lr: 6.2500e-05
# Epoch 56/128
# 1321/1321 [==============================] - 52s 39ms/step - loss: 0.1553 - accuracy: 0.9503 - auc: 0.9983 - recall: 0.9408 - precision: 0.9627 - f1_score: 0.9515 - val_loss: 0.3235 - val_accuracy: 0.9160 - val_auc: 0.9914 - val_recall: 0.9077 - val_precision: 0.9295 - val_f1_score: 0.9187 - lr: 6.2500e-05
# Epoch 57/128
# 1321/1321 [==============================] - 51s 38ms/step - loss: 0.1528 - accuracy: 0.9507 - auc: 0.9985 - recall: 0.9413 - precision: 0.9631 - f1_score: 0.9518 - val_loss: 0.3215 - val_accuracy: 0.9155 - val_auc: 0.9916 - val_recall: 0.9080 - val_precision: 0.9293 - val_f1_score: 0.9187 - lr: 6.2500e-05
# Epoch 58/128
# 1321/1321 [==============================] - 48s 36ms/step - loss: 0.1537 - accuracy: 0.9508 - auc: 0.9985 - recall: 0.9414 - precision: 0.9631 - f1_score: 0.9520 - val_loss: 0.3217 - val_accuracy: 0.9155 - val_auc: 0.9916 - val_recall: 0.9077 - val_precision: 0.9294 - val_f1_score: 0.9186 - lr: 3.1250e-05
# Epoch 59/128
# 1321/1321 [==============================] - 48s 36ms/step - loss: 0.1512 - accuracy: 0.9509 - auc: 0.9985 - recall: 0.9419 - precision: 0.9633 - f1_score: 0.9523 - val_loss: 0.3172 - val_accuracy: 0.9147 - val_auc: 0.9920 - val_recall: 0.9064 - val_precision: 0.9302 - val_f1_score: 0.9183 - lr: 3.1250e-05
# Epoch 60/128
# 1321/1321 [==============================] - 48s 36ms/step - loss: 0.1500 - accuracy: 0.9521 - auc: 0.9985 - recall: 0.9428 - precision: 0.9642 - f1_score: 0.9530 - val_loss: 0.3271 - val_accuracy: 0.9165 - val_auc: 0.9911 - val_recall: 0.9087 - val_precision: 0.9296 - val_f1_score: 0.9192 - lr: 3.1250e-05
# Epoch 61/128
# 1321/1321 [==============================] - 49s 37ms/step - loss: 0.1488 - accuracy: 0.9530 - auc: 0.9984 - recall: 0.9438 - precision: 0.9646 - f1_score: 0.9539 - val_loss: 0.3222 - val_accuracy: 0.9157 - val_auc: 0.9914 - val_recall: 0.9090 - val_precision: 0.9290 - val_f1_score: 0.9191 - lr: 3.1250e-05
# Epoch 62/128
# 1321/1321 [==============================] - 48s 36ms/step - loss: 0.1494 - accuracy: 0.9523 - auc: 0.9985 - recall: 0.9429 - precision: 0.9638 - f1_score: 0.9529 - val_loss: 0.3251 - val_accuracy: 0.9158 - val_auc: 0.9912 - val_recall: 0.9090 - val_precision: 0.9285 - val_f1_score: 0.9188 - lr: 3.1250e-05
# Epoch 63/128
# 1321/1321 [==============================] - 50s 38ms/step - loss: 0.1506 - accuracy: 0.9515 - auc: 0.9985 - recall: 0.9428 - precision: 0.9639 - f1_score: 0.9528 - val_loss: 0.3216 - val_accuracy: 0.9175 - val_auc: 0.9913 - val_recall: 0.9100 - val_precision: 0.9303 - val_f1_score: 0.9202 - lr: 3.1250e-05
# Epoch 64/128
# 1321/1321 [==============================] - 48s 37ms/step - loss: 0.1472 - accuracy: 0.9529 - auc: 0.9984 - recall: 0.9440 - precision: 0.9647 - f1_score: 0.9539 - val_loss: 0.3231 - val_accuracy: 0.9159 - val_auc: 0.9913 - val_recall: 0.9085 - val_precision: 0.9294 - val_f1_score: 0.9190 - lr: 1.5625e-05
# Epoch 65/128
# 1321/1321 [==============================] - 55s 42ms/step - loss: 0.1491 - accuracy: 0.9526 - auc: 0.9985 - recall: 0.9433 - precision: 0.9646 - f1_score: 0.9535 - val_loss: 0.3187 - val_accuracy: 0.9165 - val_auc: 0.9917 - val_recall: 0.9087 - val_precision: 0.9299 - val_f1_score: 0.9194 - lr: 1.5625e-05
# Epoch 66/128
# 1321/1321 [==============================] - 50s 37ms/step - loss: 0.1503 - accuracy: 0.9522 - auc: 0.9984 - recall: 0.9427 - precision: 0.9646 - f1_score: 0.9533 - val_loss: 0.3209 - val_accuracy: 0.9168 - val_auc: 0.9913 - val_recall: 0.9096 - val_precision: 0.9305 - val_f1_score: 0.9201 - lr: 1.5625e-05
# Epoch 67/128
# 1321/1321 [==============================] - 51s 39ms/step - loss: 0.1504 - accuracy: 0.9523 - auc: 0.9985 - recall: 0.9429 - precision: 0.9646 - f1_score: 0.9534 - val_loss: 0.3198 - val_accuracy: 0.9163 - val_auc: 0.9914 - val_recall: 0.9084 - val_precision: 0.9303 - val_f1_score: 0.9194 - lr: 1.5625e-05

# %%
import pandas as pd

HISTORY_CSV = pd.DataFrame(history.history)
HISTORY_CSV.to_csv("/kaggle/working/history.csv")


model.save("/kaggle/working/EfficientNetV2B0-Adversarial-GTSRB.h5")
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from sklearn.metrics import confusion_matrix

# Generate predictions
y_pred_classes = np.array([])
y_true = np.array([])
class_names = os.listdir('/kaggle/input/adversarial-gtsrb-data/Adversarial-GTSRB-Data/')

for x, y in val_data:
    y_pred_classes = np.concatenate([y_pred_classes, np.argmax(model.predict(x, verbose=0), axis=1)])
    y_true = np.concatenate([y_true, np.argmax(y.numpy(), axis=-1)])
    
# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(20, 20))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.PuRd)
plt.title('Confusion Matrix')
plt.colorbar(shrink=0.5)
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=90)
plt.yticks(tick_marks, class_names)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# # Plot the text on each cell
# thresh = cm_normalized.max() / 2.
# for i in range(cm.shape[0]):
#     for j in range(cm.shape[1]): 
#         plt.text(j, i, format(cm[i, j], '.2f'),
#                  horizontalalignment="center",
#                  color="white" if cm_normalized[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show('Predicted label')
plt.show()

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import numpy as np
import pandas as pd

FP = cm.sum(axis=0) - np.diag(cm) 
FN = cm.sum(axis=1) - np.diag(cm)
TP = np.diag(cm)
TN = cm.sum() - (FP + FN + TP)

accuracy = (TP + TN) / (TP + TN + FP + FN)
error_rate = 1 - accuracy

error_rate_dict = {class_names[i]: error_rate[i]*100 for i in range(len(error_rate))}
df = pd.DataFrame(list(error_rate_dict.values()), columns=['Error Rate'])
df.index = error_rate_dict.keys()

df
# Out:
#                                Error Rate
# Speed limit (50kmh)              0.255676
# Go straight or right             0.276982
# Speed limit (100kmh)             0.407187
# Slippery road                    0.340901
# Veh _ 3.5 tons prohibited        0.563434
# Wild animals crossing            0.215431
# No passing veh over 3.5 tons     0.513719
# Bumpy road                       0.454535
# Go straight or left              0.179920
# Bicycles crossing                0.116001
# Speed limit (80kmh)              0.132573
# Priority road                    0.146777
# Beware of icesnow                0.648659
# Road narrows on the right        0.108899
# Right-of-way at intersection     0.267513
# Speed limit (70kmh)              0.097062
# Traffic signals                  0.501882
# Roundabout mandatory             0.059184
# Pedestrians                      0.220165
# Road work                        0.390616
# Keep right                       0.097062
# Speed limit (20kmh)              0.385881
# Keep left                        0.288819
# Turn left ahead                  0.688904
# Children crossing                0.288819
# No passing                       0.939845
# Stop                             0.191757
# Dangerous curve right            0.468739
# Double curve                     0.691272
# Yield                            0.667598
# Speed limit (60kmh)              0.442698
# Dangerous curve left             0.946947
# End speed + passing limits       1.044009
# End of no passing                0.835681
# General caution                  0.920906
# No vehicles                      0.859355
# End of speed limit (80kmh)       0.092327
# Speed limit (30kmh)              0.300656
# No entry                         0.184655
# Turn right ahead                 0.189389
# Speed limit (120kmh)             0.092327
# End no passing veh _ 3.5 tons    0.414289
# Ahead only                       0.134940

# %%
misclassification_rate = 1 - accuracy_score(y_pred_classes, y_true)

# Calculate Sensitivity (True Positive Rate / Recall)
sensitivity = TP / (TP + FN)

# Calculate Specificity
specificity = TN / (TN + FP)

print(f"\nMisclassification Rate: {misclassification_rate}")
# Out:
# Misclassification Rate: 0.08531994981179425

# %%
sensitivity = sensitivity*100

# Create a bar chart
plt.figure(figsize=(8, 15))
plt.barh(class_names, sensitivity, color='lightgreen')
plt.xlabel('Sensitivity (%)')
plt.gca().invert_yaxis()  # Reverse the order of classes for better readability
plt.xlim(0, 105)  # Adjust x-axis limits
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()

# Display the sensitivities on top of the bars
for i, Sensitivity in enumerate(sensitivity):
    plt.text(Sensitivity + 2, i, f'{Sensitivity}%', va='center', fontsize=10)

plt.show()

# %%
metrics = list(history.history.keys())

for metric in metrics:
    if metric.startswith('val')==False and metric!='lr':
        plt.figure(figsize=(6, 4))
        plt.plot(history.history[metric])
        plt.plot(history.history['val_'+metric])
        plt.title('Model '+metric)
        plt.ylabel(metric)
        plt.xlabel('Epoch')
        if metric.endswith('loss'):
            plt.legend(['Train', 'Validation'], loc='upper right')
        else:
            plt.legend(['Train', 'Validation'], loc='lower right')

plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

y_true_classes = y_true
num_classes = 43

# Plot ROC curve for each class (one-vs-all)
n_classes = num_classes
y_true_bin = label_binarize(y_true_classes, classes=np.arange(n_classes))
y_score = model.predict(val_data)

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves
plt.figure(figsize=(16, 25))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'ROC curve (class {i}, area = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 331/331 [==============================] - 12s 30ms/step
